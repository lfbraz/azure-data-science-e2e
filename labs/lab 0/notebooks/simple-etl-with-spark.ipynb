td><td>BR</td><td>Brazil</td><td>EduardoGomesSousa@jourrapide.com</td><td>8462</td><td>1.0</td><td>4</td><td>19</td><td>0</td><td>0</td><td>45</td><td>75</td><td>3</td><td>6087</td><td>47</td><td>Push</td><td>1</td></tr><tr><td>7</td><td>Sr.</td><td>Caio</td><td>Oliveira</td><td>65</td><td>Masculino</td><td>Rua Bananal do Rio 1016</td><td>São Paulo</td><td>São Paulo</td><td>São Paulo</td><td>05207-190</td><td>BR</td><td>Brazil</td><td>CaioRibeiroOliveira@cuvox.de</td><td>3023</td><td>0.44</td><td>10</td><td>8</td><td>0</td><td>4</td><td>3</td><td>0</td><td>5</td><td>9883</td><td>48</td><td>Email</td><td>0</td></tr><tr><td>8</td><td>Sr.</td><td>Douglas</td><td>Lima</td><td>35</td><td>Masculino</td><td>Rua Cajado de São José 925</td><td>Jaboatão dos Guararapes</td><td>PE</td><td>Pernambuco</td><td>54360-640</td><td>BR</td><td>Brazil</td><td>DouglasSousaLima@superrito.com</td><td>8161</td><td>0.83</td><td>2</td><td>11</td><td>0</td><td>4</td><td>16</td><td>122</td><td>1</td><td>9076</td><td>67</td><td>SMS</td><td>1</td></tr><tr><td>9</td><td>Sra.</td><td>Beatriz</td><td>Pinto</td><td>64</td><td>Feminino</td><td>Travessa Indigena 1720</td><td>Niterói</td><td>Rio de Janeiro</td><td>Rio de Janeiro</td><td>24060 ...

# %%
Customer.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- CodigoCliente: integer (nullable = true)
# -- Titulo: string (nullable = true)
# -- PrimeiroNome: string (nullable = true)
# -- UltimoNome: string (nullable = true)
# -- Idade: integer (nullable = true)
# -- Sexo: string (nullable = true)
# -- Endereco: string (nullable = true)
# -- Cidade: string (nullable = true)
# -- UF: string (nullable = true)
# -- UFCompleto: string (nullable = true)
# -- CEP: string (nullable = true)
# -- Pais: string (nullable = true)
# -- PaisCompleto: string (nullable = true)
# -- Email: string (nullable = true)
# -- RendaMensal: integer (nullable = true)
# -- PercentualUtilizacaoLimite: double (nullable = true)
# -- QtdTransacoesNegadas: integer (nullable = true)
# -- AnosDeRelacionamentoBanco: integer (nullable = true)
# -- JaUsouChequeEspecial: integer (nullable = true)
# -- QtdEmprestimos: integer (nullable = true)
# -- NumeroAtendimentos: integer (nullable = true)
# -- TMA: integer (nullable = true)
# -- IndiceSatisfacao: integer (nullable = true)
# -- Saldo: integer (nullable = true)
# -- CLTV: integer (nullable = true)
# -- CanalPref: string (nullable = true)
# -- Churn: integer (nullable = true)
#
# </div>

# %% [markdown]
# ## Not let's try to prepare the dataset

# %% [markdown]
# We can use `sql` language to help to explore the dataset. For this, let's create a temporary table from the spark Dataframe created above

# %%
Customer.createOrReplaceTempView('Customer_Temp')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now we can make queries in this temp table

# %%
# %sql
select * from Customer_Temp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Codig
RibeiroOliveira@cuvox.de</td><td>3023</td><td>0.44</td><td>10</td><td>8</td><td>0</td><td>4</td><td>3</td><td>0</td><td>5</td><td>9883</td><td>48</td><td>Email</td><td>0</td></tr><tr><td>8</td><td>Sr.</td><td>Douglas</td><td>Lima</td><td>35</td><td>Masculino</td><td>Rua Cajado de São José 925</td><td>Jaboatão dos Guararapes</td><td>PE</td><td>Pernambuco</td><td>54360-640</td><td>BR</td><td>Brazil</td><td>DouglasSousaLima@superrito.com</td><td>8161</td><td>0.83</td><td>2</td><td>11</td><td>0</td><td>4</td><td>16</td><td>122</td><td>1</td><td>9076</td><td>67</td><td>SMS</td><td>1</td></tr><tr><td>9</td><td>Sra.</td><td>Beatriz</td><td>Pinto</td><td>64</td><td>Feminino</td><td>Travessa Indigena 1720</td><td>Niterói</td><td>Rio de Janeiro</td><td>Rio de Janeiro</td><td>24060 ...

# %% [markdown]
# Let's check if there is any missing value

# %%
# %sql
select * 
from Customer_Temp
where CodigoCliente is null or Titulo is null or PrimeiroNome is null or  UltimoNome is null or  Idade is null or  Sexo is null or
Endereco is null or Cidade is null or  UF is null or  UFCompleto is null or  CEP is null or  Pais is null or  PaisCompleto is null or  Email is null or
RendaMensal is null or PercentualUtilizacaoLimite is null or  QtdTransacoesNegadas is null or  AnosDeRelacionamentoBanco is null or  JaUsouChequeEspecial is null or 
QtdEmprestimos is null or NumeroAtendimentos is null or  TMA is null or  IndiceSatisfacao is null or  Saldo is null or  CLTV is null or  CanalPref is null or  Churn is null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CodigoCliente</th><th>Titulo</th><th>PrimeiroNome</th><th>UltimoNome</th><th>Idade</th><th>Sexo</th><th>Endereco</th><th>Cidade</th><th>UF</th><th>UFCompleto</th><th>CEP</th><th>Pais</th><th>PaisCompleto</th><th>Email</th><th>RendaMensal</th><th>PercentualUtilizacaoLimite</th><th>QtdTransacoesNegadas</th><th>AnosDeRelacionamentoBanco</th><th>JaUsouChequeEspecial</th><th>QtdEmprestimos</th><th>NumeroAtendimentos</th><th>TMA</th><th>IndiceSatisfacao</th><th>Saldo</th><th>CLTV</th><th>CanalPref</th><th>Churn</th></tr></thead><tbody><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>24</td><td>Sr.</td><td>Joao</td><td>Barbosa</td><td>44</td><td>Masculino</td><td>Rua Padre Diogo Antônio Feijó 1984</td><td>Pindamonhangaba</td><td>SP</td><td>São Paulo</td><td>12443-150</td><td>BR</td><td>Brazil</td><td>JoaoSouzaBarbosa@armyspy.com</td><td>3615</td><td>0.9</td><td>6</td><td>5</td><td>1</td><td>2</td><td>47</td><td>42</td><td>5</td><td>1820</td><td>64</td><td>Email</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>32</td><td>Sra.</td><td>Isabelle</td><td>Barros</td><td>55</td><td>Feminino</td><td>Rua Franklin Leal 924</td><td>Araçatuba</td><td>SP</td><td>São Paulo</td><td>16013-060</td><td>BR</td><td>Brazil</td><td>IsabelleGoncalvesBarros@fleckens.hu</td><td>6139</td><td>0.31</td><td>5</td><td>11</td><td>0</td><td>0</td><td>2</td><td>6</td><td>5</td><td>4674</td><td>79</td><td>SMS</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td ...

# %% [markdown]
# There are a lot of missing values ☹
#
# So, let's lead with them with Pyspark. A simple way is just remove any row with missing data.

# %%
display(Customer.na.drop())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Codig

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Let's check the content of `UF` column as well

# %%
display(Customer.groupBy(length(col('UF'))).count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>length(UF)</th><th>count</th></tr></thead><tbody><tr><td>5</td><td>1</td></tr><tr><td>9</td><td>7</td></tr><tr><td>14</td><td>1</td></tr><tr><td>2</td><td>9939</td></tr></tbody></table></div>

# %% [markdown]
# There are some values bigger than 2 letters (pattern for `UF`). Let's see these values, maybe we can maintain and make some transformation.

# %%
Customer[length(Customer.UF) > 2].select('UF').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+
#             UF|
# +--------------+
#          Bahia|
#      São Paulo|
# Rio de Janeiro|
# +--------------+
#
# </div>

# %% [markdown]
# Indeed we can do some transformations in these values to use the same `UF` pattern

# %%
from pyspark.sql.functions import when

Customer = Customer.withColumn('UF_cleaned', when(Customer.UF == 'Bahia', 'BA').otherwise(Customer.UF))
Customer = Customer.withColumn('UF_cleaned', when(Customer.UF == 'São Paulo', 'SP').otherwise(Customer.UF_cleaned))
Customer = Customer.withColumn('UF_cleaned', when(Customer.UF == 'Rio de Janeiro', 'RJ').otherwise(Customer.UF_cleaned))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# And check again but using the column derived from the cleaning process

# %%
Customer[length(Customer.UF_cleaned) > 2].select('UF_cleaned').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
# UF_cleaned|
# +----------+
# +----------+
#
# </div>

# %% [markdown]
# Cool 😃
# Now we have the `UF_cleaned` in the correct pattern

# %% [markdown]
# ### Get the mail domain
# The mail domain can be a useful information. Let's split this data from the full mail.

# %%
# Create a new column mail_domain
Customer = Customer.withColumn('mail_domain', split(col('Email'), '@').getItem(1))

display(Customer)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CodigoCliente</th><th>Titulo</th><th>PrimeiroNome</th><th>UltimoNome</th><th>Idade</th><th>Sexo</th><th>Endereco</th><th>Cidade</th><th>UF</th><th>UFCompleto</th><th>CEP</th><th>Pais</th><th>PaisCompleto</th><th>Email</th><th>RendaMensal</th><th>PercentualUtilizacaoLimite</th><th>QtdTransacoesNegadas</th><th>AnosDeRelacionamentoBanco</th><th>JaUsouChequeEspecial</th><th>QtdEmprestimos</th><th>NumeroAtendimentos</th><th>TMA</th><th>IndiceSatisfacao</th><th>Saldo</th><th>CLTV</th><th>CanalPref</th><th>Churn</th><th>UF_cleaned</th><th>mail_domain</th></tr></thead><tbody><tr><td>1</td><td>Sra.</td><td>Fernanda</td><td>Camargo</td><td>32</td><td>Feminino</td><td>Rua Paulo Suplicy, 376</td><td>São Paulo</td><td>SP</td><td>São Paulo</td><td>54210-520</td><td>BR</td><td>Brazil</td><td>fecamargo@gmail.com</td><td>8000</td><td>0.92</td><td>5</td><td>3</td><td>0</td><td>1</td><td>7</td><td>2</td><td>4</td><td>55229</td><td>65</td><td>Push</td><td>0</td><td>SP</td><td>gmail.com</td></tr><tr><td>2</td><td>Sr.</td><td>Paulo</td><td>Dias</td><td>63</td><td>Masculino</td><td>Estrada Transcastanhal 456</td><td>Castanhal</td><td>PA</td><td>Pará</td><td>68742-200</td><td>BR</td><td>Brazil</td><td>PauloPintoDias@gustr.com</td><td>4672</td><td>0.84</td><td>0</td><td>2</td><td>1</td><td>0</td><td>15</td><td>87</td><td>3</td><td>9936</td><td>66</td><td>Email</td><td>1</td><td>PA</td><td>gustr.com</td></tr><tr><td>3</td><td>Sr.</td><td>Enzo</td><